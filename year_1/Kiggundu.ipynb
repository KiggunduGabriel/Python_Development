# %%
import pandas as pd

# %%
data=pd.read_csv("Assignment 4_Remedial (1).csv")
data
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# 0               30.0          No  Female        55-59     White      Yes
# 1                0.0          No  Female  80 or older     White       No
# 2               30.0          No    Male        65-69     White      Yes
# 3                0.0          No  Female        75-79     White       No
# 4                0.0         Yes  Female        40-44     White       No
# ...              ...         ...     ...          ...       ...      ...
# 319790           0.0         Yes    Male        60-64  Hispanic      Yes
# 319791           0.0          No    Male        35-39  Hispanic       No
# 319792           0.0          No  Female        45-49  Hispanic       No
# 319793           0.0          No  Female        25-29  Hispanic       No
# 319794           0.0          No  Female  80 or older  Hispanic       No
#
#        PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0                   Yes  Very good        5.0    Yes            No        Yes
# 1                   Yes  Very good        7.0     No            No         No
# 2                   Yes       Fair        8.0    Yes            No         No
# 3                    No       Good        6.0     No            No        Yes
# 4                   Yes  Very good        8.0     No            No         No
# ...                 ...        ...        ...    ...           ...        ...
# 319790               No       Fair        6.0    Yes            No         No
# 319791              Yes  Very good        5.0    Yes            No         No
# 319792              Yes       Good        6.0     No            No         No
# 319793               No       Good       12.0     No            No         No
# 319794              Yes       Good        8.0     No            No         No
#
# [319795 rows x 18 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  object
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  object
#  3   AlcoholDrinking   319795 non-null  object
#  4   Stroke            319795 non-null  object
#  5   PhysicalHealth    319795 non-null  float64
#  6   MentalHealth      319795 non-null  float64
#  7   DiffWalking       319795 non-null  object
#  8   Sex               319795 non-null  object
#  9   AgeCategory       319795 non-null  object
#  10  Race              319795 non-null  object
#  11  Diabetic          319795 non-null  object
#  12  PhysicalActivity  319795 non-null  object
#  13  GenHealth         319795 non-null  object
#  14  SleepTime         319795 non-null  float64
#  15  Asthma            319795 non-null  object
#  16  KidneyDisease     319795 non-null  object
#  17  SkinCancer        319795 non-null  object
# dtypes: float64(4), object(14)
# memory usage: 43.9+ MB

# %% [markdown]
# Finding the relationship betweem BMI and Kidney disease

# %%
# %pip install datascrubber
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: datascrubber in c:\users\gundu g\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (0.1.5)
# Requirement already satisfied: matplotlib in c:\users\gundu g\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from datascrubber) (3.9.2)
# Requirement already satisfied: missingno in c:\users\gundu g\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from datascrubber) (0.5.2)
# Requirement already satisfied: numpy in c:\users\gundu g\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from datascrubber) (2.1.1)
# Requirement already satisfied: openpyxl in c:\users\gundu g\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from datascrubber) (3.1.5)
# Requirement already satisfied: pandas in c:\users\gundu g\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from datascrubber) (2.2.2)
# Requirement already satisfied: scikit-learn in c:\users\gundu g\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from datascrubber) (1.5.2)
# Requirement already satisfied: scipy in c:\users\gundu g\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from datascrubber) (1.14.1)
# Requirement already satisfied: seaborn in c:\users\gundu g\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from datascrubber) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gundu g\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->datascrubber) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\gundu g\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->datascrubber) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gundu g\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->datascrubber) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\gundu g\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->datascrubber) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\gundu g\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->datascrubber) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\gundu g\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->datascrubber) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\gundu g\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->datascrubber) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gundu g\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->datascrubber) (2.9.0.post0)
# Requirement already satisfied: et-xmlfile in c:\users\gundu g\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openpyxl->datascrubber) (1.1.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gundu g\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas->datascrubber) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\gundu g\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas->datascrubber) (2024.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\gundu g\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn->datascrubber) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\gundu g\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn->datascrubber) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\gundu g\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.7->matplotlib->datascrubber) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
data.boxplot(column="BMI",by="KidneyDisease",figsize=(18,10))
# Out:
# <Axes: title={'center': 'BMI'}, xlabel='KidneyDisease'>

# %%
import scipy.stats

from scipy.stats import f_oneway
def test(data, BMI, KidneyDisease):
    Group_data = [
            group[BMI].values for _, group in data.groupby(KidneyDisease)
    ]
    f_starts,p_value=f_oneway(*Group_data)
    if p_value > 0.05:
        print(f"{BMI} is not correlated with {KidneyDisease} with a p_value of {p_value}")
    elif p_value < 0.05:
        print(f"{BMI} is correlated with {KidneyDisease} with a p_value of {p_value}")
        
test(data, 'BMI','KidneyDisease')
# Out:
# BMI is correlated with KidneyDisease with a p_value of 1.7223211696873605e-181

# %% [markdown]
# FINDING THE RELATIONSHIP BETWEEN KIDNEY DISEASE AND AGECATEGORY

# %%
import scipy.stats as sp

# %%
#import the dataset and rename it
remedial = pd.read_csv("Assignment 4_Remedial (1).csv")
remedial.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  object
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  object
#  3   AlcoholDrinking   319795 non-null  object
#  4   Stroke            319795 non-null  object
#  5   PhysicalHealth    319795 non-null  float64
#  6   MentalHealth      319795 non-null  float64
#  7   DiffWalking       319795 non-null  object
#  8   Sex               319795 non-null  object
#  9   AgeCategory       319795 non-null  object
#  10  Race              319795 non-null  object
#  11  Diabetic          319795 non-null  object
#  12  PhysicalActivity  319795 non-null  object
#  13  GenHealth         319795 non-null  object
#  14  SleepTime         319795 non-null  float64
#  15  Asthma            319795 non-null  object
#  16  KidneyDisease     319795 non-null  object
#  17  SkinCancer        319795 non-null  object
# dtypes: float64(4), object(14)
# memory usage: 43.9+ MB

# %%
#Visualizing the relationship between agecategory and kidneydisease
age_kidney = pd.crosstab(index = remedial['AgeCategory'], columns=remedial['KidneyDisease'])

from scipy.stats import chi2_contingency
chi_sq_result = chi2_contingency(age_kidney)
print(f"p_value is {chi_sq_result[1]}.")
# Out:
# p_value is 0.0.

# %% [markdown]
# From the above tests we notice that the p-values for both BMI and AgeCategory in relation to KidneyDisease are less than 0.05 which implies that both BMI and AgeCategory are correlated with KidneyDisease. Hence BMI and AgeCategory are key indicators of KidneyDisease.

# %% [markdown]
#    NUMBER 2 THE DISTRIBUTION OF PROBABILITY OF A HEALTH WORKER

# %%
#Finding the marginal probability of PhysicalHealth
bins_ph = [0, 5, 10, 15, 20, 25, 30, 35]
labels_ph = ['0-5', '5-10', '10-15', '15-20', '20-25', '25-30', '30-35']

## create a new column with the binned data
data['PhysicalHealth'] = pd.cut(data['PhysicalHealth'], bins = bins_ph, labels=labels_ph, right=False)

## Calculate the Marginal Probabilities
ph_prob = data['PhysicalHealth'].value_counts(normalize=True).sort_index()
ph_prob
# Out:
# PhysicalHealth
# 0-5      0.828790
# 5-10     0.045682
# 10-15    0.028540
# 15-20    0.017070
# 20-25    0.012646
# 25-30    0.006267
# 30-35    0.061005
# Name: proportion, dtype: float64

# %% [markdown]
# The distribution of the PhysicalHealth ptobabilities is not uniform

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Visualising the distribution
sns.histplot(data=data,x='PhysicalHealth',kde=True,stat='probability')
plt.title('Distribution of probabilities')
plt.show()

# %% [markdown]
# As we can see that the probabilities of PhysicalHealth are not normally

# %% [markdown]
# THE PROBABILITY THAT A PERSON WHO SMOKES HAS SKINCANCER(PROBABILITY A PERSON HAS SKIN CANCER GIVEN THEY SMOKE)

# %%
smoke = data[data['Smoking'] == 'Yes']
skincancer = data[data['SkinCancer'] == 'Yes']

#Event of both being female and  having a Y status
joint_event = data[(data['Smoking'] == 'Yes') & (data['SkinCancer'] == 'Yes')]

#Probability of both female and Y status
joint_prob = len(joint_event)/len(data)
joint_prob

smoke_prob = len(smoke)/len(data)
smoke_prob

conditional_probability = joint_prob/smoke_prob
print("The probability for a person smoking to have skin cancer is:", conditional_probability)
# Out:
# The probability for a person smoking to have skin cancer is: 0.10503532765260637

# %% [markdown]
# RELATIONSHIP BETWEEN BMI AND SLEEPTIME

# %%
#Visualising the relationship between BMI and SleepTime using a scatterplot
data.plot.scatter(x='SleepTime', y='BMI', figsize=(10,5), title='SleepTime Vs BMI')
# Out:
# <Axes: title={'center': 'SleepTime Vs BMI'}, xlabel='SleepTime', ylabel='BMI'>

# %%
#Carrying out a statistical test
CorrelationData=data[['SleepTime', 'BMI']].corr()
CorrelationData
# Out:
#            SleepTime       BMI
# SleepTime   1.000000 -0.051822
# BMI        -0.051822  1.000000

# %% [markdown]
# There is a low negative correlation between Sleeptime and BMI

# %% [markdown]
# QN.5 BASED ON VARIABLE HEARTDISEASE WHICH GENHEALTH STATUS WOULD YOU ADVISE PATIENTS?

# %%
#Visualise the relationship between the two variables using a barplot 
CrosstabResult=pd.crosstab(index=data['GenHealth'],columns=data['HeartDisease'])
CrosstabResult

import matplotlib
# %matplotlib inline
CrosstabResult.plot.bar()
# Out:
# <Axes: xlabel='GenHealth'>

# %% [markdown]
# I would advise  patients to maintain a very good health status since most patients with very good Genhealth have no HeartDisease
